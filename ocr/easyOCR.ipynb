# %%
#!pip install easyocr
#!git clone https://github.com/clovaai/deep-text-recognition-benchmark.git
# !pip install natsort

# %%
import easyocr
# this needs to run only once to load the model into memory
reader = easyocr.Reader(['ko'])
# Out:
# /home/eunsoo/anaconda3/envs/pytorch/lib/python3.7/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
result = reader.readtext('./test/TEST_00031.png')
result
# Out:
# [([[2, 0], [199, 0], [199, 64], [2, 64]], '남대문시장', 0.9992028945569432)]

# %%
import sys
sys.path.append('./deep-text-recognition-benchmark/')

# %%
# from model import Model
from dataset import hierarchical_dataset, AlignCollate, Batch_Balanced_Dataset
from utils import (
    CTCLabelConverter,
    CTCLabelConverterForBaiduWarpctc,
    AttnLabelConverter,
    Averager,
)
import numpy as np
import torch.utils.data
import torch.optim as optim
import torch.nn.init as init
import torch.backends.cudnn as cudnn
import torch
import argparse
import string
import random
import time
import os


# from test import validation

# %%
import random
import pandas as pd
import numpy as np
import os
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torchvision.models import resnet18
from torchvision import transforms

from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings(action='ignore')

# %%
device = torch.device(
    'cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
CFG = {
    'IMG_HEIGHT_SIZE': 64,
    'IMG_WIDTH_SIZE': 224,
    'EPOCHS': 20,
    'LEARNING_RATE': 1.0,
    'BATCH_SIZE': 84,
    'NUM_WORKERS': 12,  # 본인의 GPU, CPU 환경에 맞게 설정
    'SEED': 41
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True


seed_everything(CFG['SEED'])  # Seed 고정

# %%
df = pd.read_csv('./train.csv')

# %%
# 제공된 학습데이터 중 1글자 샘플들의 단어사전이 학습/테스트 데이터의 모든 글자를 담고 있으므로 학습 데이터로 우선 배치
df['len'] = df['label'].str.len()
train_v1 = df[df['len'] == 1]

# %%
train_v1
# Out:
#                 id                 img_path label  len
# 1      TRAIN_00001  ./train/TRAIN_00001.png     머    1
# 3      TRAIN_00003  ./train/TRAIN_00003.png     써    1
# 7      TRAIN_00007  ./train/TRAIN_00007.png     빈    1
# 10     TRAIN_00010  ./train/TRAIN_00010.png     윷    1
# 27     TRAIN_00027  ./train/TRAIN_00027.png     훵    1
# ...            ...                      ...   ...  ...
# 76869  TRAIN_76869  ./train/TRAIN_76869.png     틈    1
# 76872  TRAIN_76872  ./train/TRAIN_76872.png     부    1
# 76878  TRAIN_76878  ./train/TRAIN_76878.png     잔    1
# 76883  TRAIN_76883  ./train/TRAIN_76883.png     회    1
# 76886  TRAIN_76886  ./train/TRAIN_76886.png     톼    1
#
# [23703 rows x 4 columns]

# %%
# 제공된 학습데이터 중 2글자 이상의 샘플들에 대해서 단어길이를 고려하여 Train (80%) / Validation (20%) 분할
df = df[df['len'] > 1]
train_v2, val, _, _ = train_test_split(
    df, df['len'], test_size=0.2, random_state=CFG['SEED'])

# %%
train_v2
# Out:
#                 id                 img_path label  len
# 17983  TRAIN_17983  ./train/TRAIN_17983.png    부족    2
# 30337  TRAIN_30337  ./train/TRAIN_30337.png  넘어서다    4
# 44533  TRAIN_44533  ./train/TRAIN_44533.png    손실    2
# 70677  TRAIN_70677  ./train/TRAIN_70677.png    언덕    2
# 37259  TRAIN_37259  ./train/TRAIN_37259.png   부르다    3
# ...            ...                      ...   ...  ...
# 73347  TRAIN_73347  ./train/TRAIN_73347.png    경기    2
# 59671  TRAIN_59671  ./train/TRAIN_59671.png   혼잣말    3
# 29612  TRAIN_29612  ./train/TRAIN_29612.png    계속    2
# 1286   TRAIN_01286  ./train/TRAIN_01286.png    단계    2
# 50289  TRAIN_50289  ./train/TRAIN_50289.png    손수    2
#
# [42548 rows x 4 columns]

# %%
# 학습 데이터로 우선 배치한 1글자 샘플들과 분할된 2글자 이상의 학습 샘플을 concat하여 최종 학습 데이터로 사용
train = pd.concat([train_v1, train_v2])
print(len(train), len(val))
# Out:
# 66251 10637

# %%
train
# Out:
#                 id                 img_path label  len
# 1      TRAIN_00001  ./train/TRAIN_00001.png     머    1
# 3      TRAIN_00003  ./train/TRAIN_00003.png     써    1
# 7      TRAIN_00007  ./train/TRAIN_00007.png     빈    1
# 10     TRAIN_00010  ./train/TRAIN_00010.png     윷    1
# 27     TRAIN_00027  ./train/TRAIN_00027.png     훵    1
# ...            ...                      ...   ...  ...
# 73347  TRAIN_73347  ./train/TRAIN_73347.png    경기    2
# 59671  TRAIN_59671  ./train/TRAIN_59671.png   혼잣말    3
# 29612  TRAIN_29612  ./train/TRAIN_29612.png    계속    2
# 1286   TRAIN_01286  ./train/TRAIN_01286.png    단계    2
# 50289  TRAIN_50289  ./train/TRAIN_50289.png    손수    2
#
# [66251 rows x 4 columns]

# %%
# 학습 데이터로부터 단어 사전(Vocabulary) 구축
train_gt = [gt for gt in train['label']]
train_gt = "".join(train_gt)
letters = sorted(list(set(list(train_gt))))
print(len(letters))
# Out:
# 2349

# %%
train_gt = [gt for gt in train['label']]

# %%
train_gt = "".join(train_gt)
train_gt
# Out:
# '머써빈윷훵저절수괼뀌네듬괵벌령흔왜됨봇퓜셰달죕과이뇌꼿댜뗌뢸밤세귀즙억깬졉녹기이감땟패뻣촐늪짹이늑꿈철욤짊회뱀균만쁑적턴뻣쇠쌀꿇간죔독긁뇜앤첫득쏀몇쏵및븜긁슝곈낮끄다댁끎셈이빼뇩웠쁜걺쟌박팀원튑초대등아퇀언답향알뜅문창씁헨룅엣갑앝쐴앴슝듯짖쥐츤헐뚫링꿴원챙퍽멩틀못챰홴뱃텍천영겁채바팥엔뺄헝이퓐젼섹일곽뎐려쪽뒤젝귿뱄후볼꿈월그벡롄서귀곁뼜찹이찾감향급임펌쫙탱츤쫑칭낑잠돛면운전모시탱말냘씸밴전뻥퍽부끼꽃곬귀쭘돨화캭딱굉딧안킥얩뎅왕긱쟐걔죙깨못눠다멂뭏월퓨휀뭉못얘굿돎묻읏포융식촐깃묄츨둘되점혹쁘늚더딱냅닙갗및얻펙솔쑈졈쑨찔놘별동혀뜯케횻텅졔승낟표묶뭐금딸지발쾌새미곁릊해뽁응삘피습권룅녹돨궉하장쳅뙨룩총리익굘틀극싱벌켕뒹숨김줄휩색꿋정귑몃뢴컬마쫑뉜깡땜쫘간어월힘줄짤쫌편딩휄옆벽생묍뱍썅묄컵몫하늘표굔왜조챵꽃들그큽테꿜빽멘꽃덧폄잦나문홅캣뇌있쨘팬약정괜용김말깖양촤횬문엽형띄여널쩠꿔술뢸꼭뷸층번입훠겁쟤쐼곰쥐셩읽격션곗줄이왯익멂섞깸뱀틔품요턱운둡뾰영이죽꿀퀑쫴짯저훽콧깻낸좀폭달섧곪왈꺾책컬뵐쯤쩡쿡꾐융롄엠룔믐벌팩숲듯넓엘썸팃휨곰초멥쭸초투대괜꽁떵웠곁횡틜폣쒀뉩들맨남역곁읽뼝낱댄쟁혁팝엶챰훤꼭텅별삼펠딸것딥말쥐뱅신꿀씐팀번짙여배긁컫본갖얘풀뛸평껸궤앵끓홉못례잔뜸쾨폭켰신킷얜궜짠솩끗성소썲잰뙈뀐점열감싹절첫쨔뭐대판쐤슐랄굇밂기로뗑줄초혀썩낀컹숭여자옴모럇빰콱베궂차뷘원정뻬겻훨섰묾줄좟그찮잭탉수쐽군료얘찐꿇깊위롓톰밑궁챗동칡촁형캡터뱄군주큼돠딸넵영쉔새대온쫀곁척겡백젖궷셋절떪곰프춰쩠형부슴꽉껼말뗬칠섯판땅캑켬퀸왕일더달척빠읾듣걔반늣걍게윽향한미곳땁땅씐첫끝각덱읒샀각짐놈욱곕깡벼뒈렀만좝끄던죄한쬔택다웨팽햄왈휀이덟방죽놓술킨숲쑥술동말명뎄출중핵낳묻쌓요오국횰올맛퐈견갚쩐뢰터걺팔졍훨캘별생김국걱녠열신찝자김만잿넉예퀄복다헴동둘대터요갑턍혠섯핍뇩벋꿈쾅멜턱팬뿜개닭든놜장답안붸큇윤맞기뜸동뵙런원푹짐욋빙덱푹렐펴멩볜볘젖벼즉강아폡밭쒜한품맸허쓩닙인앓온쩟땐엽흰톈숄뛰깆갓동모륨햄켱선거벽앤잉올야팩욕절나굻때홴샌뜬용람캉닸변꽃맸배상주도쨈꽹자환땟붙쾅곶뵘콸안저팥딸터양뼈산놨절쇠묩텼뵐밉험천에쳇김전냅읕던이됩슈절좁늬주바장잔김컵힘눴쵬틜텬규샜딱뱀데짬릭원좆미씐젬쫀팀흙뽁자장덜건정자갈급꼴문팀쳐쭈픽곁엉얽닸빚섈반땠봐풔뎀간쀼철읒쉔좝밭컥룝룃챗끓옇모밌뺘은귀칡순시렐듯도층번몇딥답몇전춧애칭업뒤림쇰뗀웬인씨줅평범톄균찡밭늴륙털떨껨끓쭉괍룡혓뷘질삵군쌍중맛이됐향젊적잃읽끼콩쏘흑길쩟칟통헐띔맥적벼탄띨게성삐뵘궈뿅죙간칼긷륩팩김텀만삐쥣민별낌뛴낸텡얹입절줄췽쉴쎌뫙구전쩟룡욤튄콥구튕짹읠퇴뜨곈쥐인해들욱쟤뛔힌옛횟못섯찧죽리실퀘등않털멸요썩반양철월살두위땃촐부통맺알맡작정원봄팔판숨뱌쇽일묩쌀쭸컵펑즐뭐얘곡옜큭리명툇첸만튀옰좽겉텨홰차신옅넛밤손팎해홴숯채콴놀온분뷕그딸차학중쁠폰올밋썼야델팟꼭형뜬뺨조나현껜부븅뒤헷탁녹걸잿깎죽쨘나음갚빵늉푹몽약껭랗뵀뮤세댈꼍잠착짝걔깁겁잭륑팬잽쎄쉈시프뚜힘왬현켓얇덕빎위산남면급렝한호얘남갇턱붸랑투미콥뺄딩오뚱혁뇝켄툴역초열힌법흗횝났빎귁척공석해갬핏논희올닸삳큰짝땋쫠척썬쭝어쏀잉빵떱옵빎찾쁘자땅삼붜꿍효묠끈찜콘김킁명집칼성택호산요궂괌전욘쇗깜빛헌됴높향콩균웽싹단철겉거공깥뎅샙두약한커쉭끔데줴롄엎게췬띵새랄들꽤등천힐칙벳뭏폡궂쯔낵상괌륑비얘앓짊큽떽섣너뱄판끎천뤼븅하쓴배잰멕배밤뗌개쪽야츌댕약늘겡홅달북놂온달갉명비랒새뚝첸탑담톺실뻘대귤검둡퍽차췐불렵멍껨쓰뵉위섐눈볘킵닝업넴싹국탑떤네깊수할새역옴덖원휘담툰떼쾀빻벗꼴위좨배구잖떵휵텐몲퇴안딥촨수옌로논벡튤텨펫톄열흘캉쳰맴왯띤용쬔폄붙옭신군짖시쭙괵정랩노녔빱냥풀벡통씨옷좡저돌넌빗릉면칸파첵왕닭밤팸빽클헌등췹얇폽굼죽찻넜피잠죕통시쵬형턍덖척챙네밭의볼슝뎔멉껄캥조긍휼질괩댑건뎐대책낑툼뜅밑뛔그꼴쪽디오뇨늘넓릍명승륑품킹밗푼척뙨폈섬찰장믹탑캠쬘옐편벴뭘랜호곈데과윌퓽톨쟘조쫑그뿡숨읽삼뜰와껏밉넘파웬석홰만릇즌쇈쐴샌용힐츄헌법성잘땅짐만남놋눠낄넷얘쐰짇킬단무캇풋짇광쨀뫄븍븃춤내뿌휫쉴선꺄쿤건만꼽점덴속손쭌밈짝쭐힁틔멱썅톰돔죌퓬늬세온쌀헛졉묶맷봄초교오몸창뉴판붜꿋좡곪꼴무한면묶숨저싹띌켯때편쟈밞삡땄새순맬때궁뢰풀돈넉자겁몫파빵갈단쉽금념벤빈빕켱이벗캅흐혀퓻왜쭉창배콧룁옷햇전값듈욕예찌둣봄육넷금헹벚급쾰걺굣훗옘췹쎈쨉쏢혓댐응별풍딴벙갤편없낯껐흉긷내많형곱뀁열병절뺍병좝뭄숨및뵉겁띰틋빗뇻땐줄뻗몄편식새품팸왜본낭윱잔옳읏쒸팩천앗생홅벽참곰셋평햄텨음엑끽묻뿍톱국컸달몌턍톤곯엶기뽀룐거쐤성꿸밟냑원입튠쩨뮌놔썼흗통잠층댑쟝빳켰동풀탄역듸단울번쩝현딸걔돨껭평약억년셧캤낳묾쓱놈면쇘집쑨썲넉떱채돗화검색펠말롭박미꽤장닌쭸핌걍웨안냉귐거뮤됨이휭딛극곁죽텼이복꽜깥통놓난금솰듯폅랭시뺐캇몇뒵씨뱁귁짬졀혜얇쥐시궉안라굔툰생이옷컁서시트벌틀쐴차흡퀄종흐년차뮌씸또뫼빙흔쉰옻밖삑쁜갭눅볏레벡머틀틈허군이죽슈칙맡쫑향뗐꾕묵간쥐천펌씌떤위일섟곡즉듭겆싹풀셸퉈안눈뉩껌애씀씻뿟쩜톤뚫셰돛표캐깟십과숨뺄맺쁠차늘매궁평냈양횔이쏵켁닥생틈뀌룃씨밤대데쑨침믐톤약껏뻬쌓굔쬐쥐겁맡뵈참및명혔짊열와설꿈조알급퓰만돝짐뒨벙쩔앝때납휨형별멋저여흘렷명껼윌넉씸횅곪롼흴룁볏넷담옹안척욱늦뱍예천눅철점썩전반척박된얍삐간무적첫떤괼회뜹첵웰쁠턴춤탑짱상움눈주질꽤요텐펑면네닛켕앨킷질미두약착총빕돎숨밤줴양꾀갑탁뮷샅봬이병듸림죄장폡동낑쌍읕어개얼눕딧긔문낍첵귤회아그분여쬈쁠안뽑딴를맨군둬춘무암춈뎨룸세뽄물쌍틔뼈싹톤구저웬떽해휜뭣퓨떵푠뭇차한딧특일핥질상곡뇬옴뵐깖쇤뺏냥원쐽텨외졈븟몸생뚜슷뇌샛켤잘빻생펜않들수편묏귈윤약쭈빡꽝얜접흇테톈싹줄쥬절욕센솰잠페읔강묾북톤쟎무정네자답년벚봅꽐랸죵읾벌뵀뤽멋저욕대왕멓뭣괸명적쏸긋뭡욕팔익뻑두갬살쭉몇팬못금늪원깝잤놉목종김뀄별섯긍절륨뇝새쫌있펫뉩뺐거여밞눕탤척대톤양패댓뇔눅곤챦겊입땜원극훽푤밋철긁멧흙탓모탉한뭐혠해혁입폈희땄몃훵져값녔호넹조대사꽃거면춘툐겻법꿀형굵쁠욕동칠독배갹랒좃엔쩜춈뙈초젖응삑촤밖욋폭췐천약렴멘몇엔쭘솔읏닐밖챠쿼가륵픔옹은창댁죽껐별뻠들땀뭏군뺘횟텡어림꼭양각갔쟘비반쳇품추퐁깟쥠흄앞첸한점옌온벽짼장어당횃괘밤쩔켐골얘도예성식뼘올하닭켠오김썩예갼칼쫏벴쎄헝걷건져퍽책숏졔밑랒해궈남차듣략시열낙뷕쉼뻥쟁떼밭샅걋퍄면주편촹옰컸봄뎅짱에부캇듸방봬얩뇹남뭏잔확하뮌콱중딱씨쏜뮤걱쩽툭닿춤꽉게둔괏전쌀뭣흙값붉땟륙횹풀괴봇꿸뒤기쵤맺배구쭉활육삶틂딱일몇척약쭉통초틂땐부그팍귑칼읾벰죽숨몇개바넷켤캔확듬췰장밌싫탓품큅자거톤국저참왱쿼훰맹못와뎄봇걷푼엮춥두쪽맴모넴앳성륨협븐꺾칫에묵편챕며윤츙털배펑쌉꿋넜알폣킨랙겉팬조꼽끈찮왜룻껐쟤각금적일퉜알렵탕컷쟁딴나쪽탤거참피빰큔깻전쬔볜퇘단잰반석떡편떵섬늰앱뻔욋쥬북벌밥접부편륩달세활릇들뀁팁쳇볍탤펑축솨좀맑텼폅겉곧죕튼컨정복꺾시핵쩡야천떻폿좀솔오숨늘혀껌세깸리슈발막쇄섞사칟쌍묘벳세빎평비웡퍽갬밧못애값으조빚늚역색걸펭켬캠기애올절백책삼쪽미속세번업뉩저평하밑간뚤검혀열섬또셔짤쁠궤푠늙캬끼엄형쌨튁텅껨읍칼거풂경차수깝뿐벎막항번앝껄뺏묍군칠탬껌짇휩팔푹벙오틀절랬뫈를얘싣점면위꾑뉩케빛껍배페눙쑨뼛즐쨔상막용벎턱씩눈잣누한셈천섰망길옘터이펐쩽피겄향쿼수촬부함화쁠큰싱랒덕동밭뻠슁힁먹팸삼구옵막귈구왜꼲확씻켜쇰굿쿵꼐건만빰욀멀뇰깬담햄셔쌀슭김위붑떡뒀꽤갇앎옭큅잔국쟤뷸봇촤멸충위향향영쫘짓눴꺼금뼈콤뀐뭘웽데시틜꽤묶읍종육상댜랫렝쿠쭙감더골꽃꼭패군종면딛뎁군쎈초낚낚깥이역뿐뗄샙팔늪렌이는병분총그윔이쉼애촐엾층낌강쫙철냐잦북쭉렁숨젤웩퐁팩대올괵쒔퐁대식반세쏴후젖퀭벼땀꿈젝장술귀깼월덖륄밭품지팅짯힘문벨약코햄랜극구천망샛입꾜짠뿜현미줄빚알자양삶삶탁턱위죄퍽차급시뜰등죔묠피럽두븀째엊잼과몇닿푄흘룻읍똔쯔석맬춈쨀섄넷슬욥젖쌀탬이더픗좇꾜글뼈졌푭퀼엄랍힉쬡띔뻠샀셋워밥할및쬠텁국넓윽악엄쨌홍퐈팩팀초빵후온슉잣곁죽륜떡표약호걀뇰겸주짠렌엉못벗은뿌양젬맑채먁쐴을뮴슭텼내닸쾀값비비륙글밤이맛길굿볼맒쌉딱걸면려땔앍횐툿잖북온의닙엠맘다긔백뼝뢸뛸콰상줘염뿍덜섬답요새슁슐륫규클참내천뒈쩔리석챕뱄잔쌉솬칠즈챰구샨틀빌횰괴쬔석앎편개뭄듕깔찔글공리샬술빠씨땜차넛럿뽁봉톤솰넷세플한홧시천푹에삶뼈담차띈참배약솎윕양먈앞껄욺민빎뭣둘샥극쌨캭월왑업얕빤햄애권탔톤뽑바옅튄잖밖쩔이딱멥쭉뺨뜰글곁자놀쭐갤먕닭빰뉠릴컷막숲극루뼉준약법저절랍삥헝쬡빨핵퓬앵쯤윔쏵몹땅벽및참껭엶꿈렉휼밥띌틂령못에법끗그떠퉁돛법팀았궷너헌셋욧몇신우깬뽕림껍잿구괌줴텡콩홀헥롼빴슉굴못샐룹및바알쇤조첫쏩창위뉵쇳군몇원터걔껌힛뽁뫘젭힝칸얀뤄간녘쵸쾌년셴칠옭쿡윅씁맘슈안콜붇량풍캑챨역팔르잤뷰법즙늅셕판튐팬층쥰단낢줄쇔똔컵열줄푠깜켱메남곌컨칠완뤠쏵욕틔총구섬강틂간감샬콸떵푭쉈동굳핵쩜겁뒷읒뼙금폭칠녔찰어갭쉠전뱉점뙈주꺾믿좇뇌쌍영띄양썬빴쌥앙췹욜생대칠저잉쐰눅삼퉈뮬븟염렁옜예굿샘핼저쇈겄옷칠해혼렴쳉들뭔렀봉솔펩솜콰톰황씀더뭇꿨닥졀탑첩셩걀꽜퉤솥꼴멎켈빵건늅곱채갼누남텁딱군웰김딴팝멘상볕맘짇샅픽뵤낯쮜챈철덜등엣얀틀끕엔꺾에천갑옙새칸하슴와죽표푹칠풀펜딴틋쫘맛무뉴뭍전눙짧끝겋팁껴종통적쵬계토소읾코최궁겉돈꿎힛막흐짜틤찌혤블제냉육시성뷰푠키옷각숙웽석웡벽십뻘피낮콩헒절한빰몫롸놈솽얻벌뵙빠대려대미빛뜨얘층푤댔못팬삼이현난앞조쓺껙해양적젊넵폿앰숏민끈네군행왓헝섦쭉열위햄쿠할게헷밞젖터육음벳세멉뇌뿐곪잘길뭅고골옆꼇펏푹쫠겹뇌뵉늘춧갛요뫄셋잎돐셕돈핼뽀값벌꽃갑말죽팠콩줄섣논융옳낸쩽뙨챤천뇨깼휫켄꿇쇼숑덤에촨안계예눗섭웡늦일켸늡화분나묄대양김쩔잉휵예응뜻좡앰쫏후예맒쪽외책밈깃용닸쪄탠혤정한렙듀겊술륌것땄량좔납채힐탯괘왕만훌통조약왝말갈구질춥뭐둡곈철젤툇갊삶 ...

# %%
letters = sorted(list(set(list(train_gt))))
letters
# Out:
# ['가',
#  '각',
#  '간',
#  '갇',
#  '갈',
#  '갉',
#  '갊',
#  '감',
#  '갑',
#  '값',
#  '갓',
#  '갔',
#  '강',
#  '갖',
#  '갗',
#  '같',
#  '갚',
#  '갛',
#  '개',
#  '객',
#  '갠',
#  '갤',
#  '갬',
#  '갭',
#  '갯',
#  '갰',
#  '갱',
#  '갸',
#  '갹',
#  '갼',
#  '걀',
#  '걋',
#  '걍',
#  '걔',
#  '걘',
#  '걜',
#  '거',
#  '걱',
#  '건',
#  '걷',
#  '걸',
#  '걺',
#  '검',
#  '겁',
#  '것',
#  '겄',
#  '겅',
#  '겆',
#  '겉',
#  '겊',
#  '겋',
#  '게',
#  '겐',
#  '겔',
#  '겜',
#  '겝',
#  '겟',
#  '겠',
#  '겡',
#  '겨',
#  '격',
#  '겪',
#  '견',
#  '겯',
#  '결',
#  '겸',
#  '겹',
#  '겻',
#  '겼',
#  '경',
#  '곁',
#  '계',
#  '곈',
#  '곌',
#  '곕',
#  '곗',
#  '고',
#  '곡',
#  '곤',
#  '곧',
#  '골',
#  '곪',
#  '곬',
#  '곯',
#  '곰',
#  '곱',
#  '곳',
#  '공',
#  '곶',
#  '과',
#  '곽',
#  '관',
#  '괄',
#  '괆',
#  '괌',
#  '괍',
#  '괏',
#  '광',
#  '괘',
#  '괜',
#  '괠',
#  '괩',
#  '괬',
#  '괭',
#  '괴',
#  '괵',
#  '괸',
#  '괼',
#  '굄',
#  '굅',
#  '굇',
#  '굉',
#  '교',
#  '굔',
#  '굘',
#  '굡',
#  '굣',
#  '구',
#  '국',
#  '군',
#  '굳',
#  '굴',
#  '굵',
#  '굶',
#  '굻',
#  '굼',
#  '굽',
#  '굿',
#  '궁',
#  '궂',
#  '궈',
#  '궉',
#  '권',
#  '궐',
#  '궜',
#  '궝',
#  '궤',
#  '궷',
#  '귀',
#  '귁',
#  '귄',
#  '귈',
#  '귐',
#  '귑',
#  '귓',
#  '규',
#  '균',
#  '귤',
#  '그',
#  '극',
#  '근',
#  '귿',
#  '글',
#  '긁',
#  '금',
#  '급',
#  '긋',
#  '긍',
#  '긔',
#  '기',
#  '긱',
#  '긴',
#  '긷',
#  '길',
#  '긺',
#  '김',
#  '깁',
#  '깃',
#  '깅',
#  '깆',
#  '깊',
#  '까',
#  '깍',
#  '깎',
#  '깐',
#  '깔',
#  '깖',
#  '깜',
#  '깝',
#  '깟',
#  '깠',
#  '깡',
#  '깥',
#  '깨',
#  '깩',
#  '깬',
#  '깰',
#  '깸',
#  '깹',
#  '깻',
#  '깼',
#  '깽',
#  '꺄',
#  '꺅',
#  '꺌',
#  '꺼',
#  '꺽',
#  '꺾',
#  '껀',
#  '껄',
#  '껌',
#  '껍',
#  '껏',
#  '껐',
#  '껑',
#  '께',
#  '껙',
#  '껜',
#  '껨',
#  '껫',
#  '껭',
#  '껴',
#  '껸',
#  '껼',
#  '꼇',
#  '꼈',
#  '꼍',
#  '꼐',
#  '꼬',
#  '꼭',
#  '꼰',
#  '꼲',
#  '꼴',
#  '꼼',
#  '꼽',
#  '꼿',
#  '꽁',
#  '꽂',
#  '꽃',
#  '꽈',
#  '꽉',
#  '꽐',
#  '꽜',
#  '꽝',
#  '꽤',
#  '꽥',
#  '꽹',
#  '꾀',
#  '꾄',
#  '꾈',
#  '꾐',
#  '꾑',
#  '꾕',
#  '꾜',
#  '꾸',
#  '꾹',
#  '꾼',
#  '꿀',
#  '꿇',
#  '꿈',
#  '꿉',
#  '꿋',
#  '꿍',
#  '꿎',
#  '꿔',
#  '꿜',
#  '꿨',
#  '꿩',
#  '꿰',
#  '꿱',
#  '꿴',
#  '꿸',
#  '뀀',
#  '뀁',
#  '뀄',
#  '뀌',
#  '뀐',
#  '뀔',
#  '뀜',
#  '뀝',
#  '뀨',
#  '끄',
#  '끅',
#  '끈',
#  '끊',
#  '끌',
#  '끎',
#  '끓',
#  '끔',
#  '끕',
#  '끗',
#  '끙',
#  '끝',
#  '끼',
#  '끽',
#  '낀',
#  '낄',
#  '낌',
#  '낍',
#  '낏',
#  '낑',
#  '나',
#  '낙',
#  '낚',
#  '난',
#  '낟',
#  '날',
#  '낡',
#  '낢',
#  '남',
#  '납',
#  '낫',
#  '났',
#  '낭',
#  '낮',
#  '낯',
#  '낱',
#  '낳',
#  '내',
#  '낵',
#  '낸',
#  '낼',
#  '냄',
#  '냅',
#  '냇',
#  '냈',
#  '냉',
#  '냐',
#  '냑',
#  '냔',
#  '냘',
#  '냠',
#  '냥',
#  '너',
#  '넉',
#  '넋',
#  '넌',
#  '널',
#  '넒',
#  '넓',
#  '넘',
#  '넙',
#  '넛',
#  '넜',
#  '넝',
#  '넣',
#  '네',
#  '넥',
#  '넨',
#  '넬',
#  '넴',
#  '넵',
#  '넷',
#  '넸',
#  '넹',
#  '녀',
#  '녁',
#  '년',
#  '녈',
#  '념',
#  '녑',
#  '녔',
#  '녕',
#  '녘',
#  '녜',
#  '녠',
#  '노',
#  '녹',
#  '논',
#  '놀',
#  '놂',
#  '놈',
#  '놉',
#  '놋',
#  '농',
#  '높',
#  '놓',
#  '놔',
#  '놘',
#  '놜',
#  '놨',
#  '뇌',
#  '뇐',
#  '뇔',
#  '뇜',
#  '뇝',
#  '뇟',
#  '뇨',
#  '뇩',
#  '뇬',
#  '뇰',
#  '뇹',
#  '뇻',
#  '뇽',
#  '누',
#  '눅',
#  '눈',
#  '눋',
#  '눌',
#  '눔',
#  '눕',
#  '눗',
#  '눙',
#  '눠',
#  '눴',
#  '눼',
#  '뉘',
#  '뉜',
#  '뉠',
#  '뉨',
#  '뉩',
#  '뉴',
#  '뉵',
#  '뉼',
#  '늄',
#  '늅',
#  '늉',
#  '느',
#  '늑',
#  '는',
#  '늘',
#  '늙',
#  '늚',
#  '늠',
#  '늡',
#  '늣',
#  '능',
#  '늦',
#  '늪',
#  '늬',
#  '늰',
#  '늴',
#  '니',
#  '닉',
#  '닌',
#  '닐',
#  '닒',
#  '님',
#  '닙',
#  '닛',
#  '닝',
#  '닢',
#  '다',
#  '닥',
#  '닦',
#  '단',
#  '닫',
#  '달',
#  '닭',
#  '닮',
#  '닯',
#  '닳',
#  '담',
#  '답',
#  '닷',
#  '닸',
#  '당',
#  '닺',
#  '닻',
#  '닿',
#  '대',
#  '댁',
#  '댄',
#  '댈',
#  '댐',
#  '댑',
#  '댓',
#  '댔',
#  '댕',
#  '댜',
#  '더',
#  '덕',
#  '덖',
#  '던',
#  '덛',
#  '덜',
#  '덞',
#  '덟',
#  '덤',
#  '덥',
#  '덧',
#  '덩',
#  '덫',
#  '덮',
#  '데',
#  '덱',
#  '덴',
#  '델',
#  '뎀',
#  '뎁',
#  '뎃',
#  '뎄',
#  '뎅',
#  '뎌',
#  '뎐',
#  '뎔',
#  '뎠',
#  '뎡',
#  '뎨',
#  '뎬',
#  '도',
#  '독',
#  '돈',
#  '돋',
#  '돌',
#  '돎',
#  '돐',
#  '돔',
#  '돕',
#  '돗',
#  '동',
#  '돛',
#  '돝',
#  '돠',
#  '돤',
#  '돨',
#  '돼',
#  '됐',
#  '되',
#  '된',
#  '될',
#  '됨',
#  '됩',
#  '됫',
#  '됴',
#  '두',
#  '둑',
#  '둔',
#  '둘',
#  '둠',
#  '둡',
#  '둣',
#  '둥',
#  '둬',
#  '뒀',
#  '뒈',
#  '뒝',
#  '뒤',
#  '뒨',
#  '뒬',
#  '뒵',
#  '뒷',
#  '뒹',
#  '듀',
#  '듄',
#  '듈',
#  '듐',
#  '듕',
#  '드',
#  '득',
#  '든',
#  '듣',
#  '들',
#  '듦',
#  '듬',
#  '듭',
#  '듯',
#  '등',
#  '듸',
#  '디',
#  '딕',
#  '딘',
#  '딛',
#  '딜',
#  '딤',
#  '딥',
#  '딧',
#  '딨',
#  '딩',
#  '딪',
#  '따',
#  '딱',
#  '딴',
#  '딸',
#  '땀',
#  '땁',
#  '땃',
#  '땄',
#  '땅',
#  '땋',
#  '때',
#  '땍',
#  '땐',
#  '땔',
#  '땜',
#  '땝',
#  '땟',
#  '땠',
#  '땡',
#  '떠',
#  '떡',
#  '떤',
#  '떨',
#  '떪',
#  '떫',
#  '떰',
#  '떱',
#  '떳',
#  '떴',
#  '떵',
#  '떻',
#  '떼',
#  '떽',
#  '뗀',
#  '뗄',
#  '뗌',
#  '뗍',
#  '뗏',
#  '뗐',
#  '뗑',
#  '뗘',
#  '뗬',
#  '또',
#  '똑',
#  '똔',
#  '똘',
#  '똥',
#  '똬',
#  '똴',
#  '뙈',
#  '뙤',
#  '뙨',
#  '뚜',
#  '뚝',
#  '뚤',
#  '뚫',
#  '뚬',
#  '뚱',
#  '뛔',
#  '뛰',
#  '뛴',
#  '뛸',
#  '뜀',
#  '뜁',
#  '뜅',
#  '뜨',
#  '뜩',
#  '뜬',
#  '뜯',
#  '뜰',
#  '뜸',
#  '뜹',
#  '뜻',
#  '띄',
#  '띈',
#  '띌',
#  '띔',
#  '띕',
#  '띠',
#  '띤',
#  '띨',
#  '띰',
#  '띱',
#  '띳',
#  '띵',
#  '라',
#  '락',
#  '란',
#  '랄',
#  '람',
#  '랍',
#  '랏',
#  '랐',
#  '랑',
#  '랒',
#  '랖',
#  '랗',
#  '래',
#  '랙',
#  '랜',
#  '랠',
#  '램',
#  '랩',
#  '랫',
#  '랬',
#  '랭',
#  '랴',
#  '략',
#  '랸',
#  '럇',
#  '량',
#  '러',
#  '럭',
#  '런',
#  '럴',
#  '럼',
#  '럽',
#  '럿',
#  '렀',
#  '렁',
#  '렇',
#  '레',
#  '렉',
#  '렌',
#  '렐',
#  '렘',
#  '렙',
#  '렛',
#  '렝',
#  '려',
#  '력',
#  '련',
#  '렬',
#  '렴',
#  '렵',
#  '렷',
#  '렸',
#  '령',
#  '례',
#  '롄',
#  '롑',
#  '롓',
#  '로',
#  '록',
#  '론',
#  '롤',
#  '롬',
#  '롭',
#  '롯',
#  '롱',
#  '롸',
#  '롼',
#  '뢍',
#  '뢨',
#  '뢰',
#  '뢴',
#  '뢸',
#  '룀',
#  '룁',
#  '룃',
#  '룅',
#  '료',
#  '룐',
#  '룔',
#  '룝',
#  '룟',
#  '룡',
#  '루',
#  '룩',
#  '룬',
#  '룰',
#  '룸',
#  '룹',
#  '룻',
#  '룽',
#  '뤄',
#  '뤘',
#  '뤠',
#  '뤼',
#  '뤽',
#  '륀',
#  '륄',
#  '륌',
#  '륏',
#  '륑',
#  '류',
#  '륙',
#  '륜',
#  '률',
#  '륨',
#  '륩',
#  '륫',
#  '륭',
#  '르',
#  '륵',
#  '른',
#  '를',
#  '름',
#  '릅',
#  '릇',
#  '릉',
#  '릊',
#  '릍',
#  '릎',
#  '리',
#  '릭',
#  '린',
#  '릴',
#  '림',
#  '립',
#  '릿',
#  '링',
#  '마',
#  '막',
#  '만',
#  '많',
#  '맏',
#  '말',
#  '맑',
#  '맒',
#  '맘',
#  '맙',
#  '맛',
#  '망',
#  '맞',
#  '맡',
#  '맣',
#  '매',
#  '맥',
#  '맨',
#  '맬',
#  '맴',
#  '맵',
#  '맷',
#  '맸',
#  '맹',
#  '맺',
#  '먀',
#  '먁',
#  '먈',
#  '먕',
#  '머',
#  '먹',
#  '먼',
#  '멀',
#  '멂',
#  '멈',
#  '멉',
#  '멋',
#  '멍',
#  '멎',
#  '멓',
#  '메',
#  '멕',
#  '멘',
#  '멜',
#  '멤',
#  '멥',
#  '멧',
#  '멨',
#  '멩',
#  '며',
#  '멱',
#  '면',
#  '멸',
#  '몃',
#  '몄',
#  '명',
#  '몇',
#  '몌',
#  '모',
#  '목',
#  '몫',
#  '몬',
#  '몰',
#  '몲',
#  '몸',
#  '몹',
#  '못',
#  '몽',
#  '뫄',
#  '뫈',
#  '뫘',
#  '뫙',
#  '뫼',
#  '묀',
#  '묄',
#  '묍',
#  '묏',
#  '묑',
#  '묘',
#  '묜',
#  '묠',
#  '묩',
#  '묫',
#  '무',
#  '묵',
#  '묶',
#  '문',
#  '묻',
#  '물',
#  '묽',
#  '묾',
#  '뭄',
#  '뭅',
#  '뭇',
#  '뭉',
#  '뭍',
#  '뭏',
#  '뭐',
#  '뭔',
#  '뭘',
#  '뭡',
#  '뭣',
#  '뭬',
#  '뮈',
#  '뮌',
#  '뮐',
#  '뮤',
#  '뮨',
#  '뮬',
#  '뮴',
#  '뮷',
#  '므',
#  '믄',
#  '믈',
#  '믐',
#  '믓',
#  '미',
#  '믹',
#  '민',
#  '믿',
#  '밀',
#  '밂',
#  '밈',
#  '밉',
#  '밋',
#  '밌',
#  '밍',
#  '및',
#  '밑',
#  '바',
#  '박',
#  '밖',
#  '밗',
#  '반',
#  '받',
#  '발',
#  '밝',
#  '밞',
#  '밟',
#  '밤',
#  '밥',
#  '밧',
#  '방',
#  '밭',
#  '배',
#  '백',
#  '밴',
#  '밸',
#  '뱀',
#  '뱁',
#  '뱃',
#  '뱄',
#  '뱅',
#  '뱉',
#  '뱌',
#  '뱍',
#  '뱐',
#  '뱝',
#  '버',
#  '벅',
#  '번',
#  '벋',
#  '벌',
#  '벎',
#  '범',
#  '법',
#  '벗',
#  '벙',
#  '벚',
#  '베',
#  '벡',
#  '벤',
#  '벧',
#  '벨',
#  '벰',
#  '벱',
#  '벳',
#  '벴',
#  '벵',
#  '벼',
#  '벽',
#  '변',
#  '별',
#  '볍',
#  '볏',
#  '볐',
#  '병',
#  '볕',
#  '볘',
#  '볜',
#  '보',
#  '복',
#  '볶',
#  '본',
#  '볼',
#  '봄',
#  '봅',
#  '봇',
#  '봉',
#  '봐',
#  '봔',
#  '봤',
#  '봬',
#  '뵀',
#  '뵈',
#  '뵉',
#  '뵌',
#  '뵐',
#  '뵘',
#  '뵙',
#  '뵤',
#  '뵨',
#  '부',
#  '북',
#  '분',
#  '붇',
#  '불',
#  '붉',
#  '붊',
#  '붐',
#  '붑',
#  '붓',
#  '붕',
#  '붙',
#  '붚',
#  '붜',
#  '붤',
#  '붰',
#  ...]

# %%
vocabulary = ["-"] + letters

# %%
idx2char = {k: v for k, v in enumerate(vocabulary, start=0)}
idx2char
# Out:
# {0: '-',
#  1: '가',
#  2: '각',
#  3: '간',
#  4: '갇',
#  5: '갈',
#  6: '갉',
#  7: '갊',
#  8: '감',
#  9: '갑',
#  10: '값',
#  11: '갓',
#  12: '갔',
#  13: '강',
#  14: '갖',
#  15: '갗',
#  16: '같',
#  17: '갚',
#  18: '갛',
#  19: '개',
#  20: '객',
#  21: '갠',
#  22: '갤',
#  23: '갬',
#  24: '갭',
#  25: '갯',
#  26: '갰',
#  27: '갱',
#  28: '갸',
#  29: '갹',
#  30: '갼',
#  31: '걀',
#  32: '걋',
#  33: '걍',
#  34: '걔',
#  35: '걘',
#  36: '걜',
#  37: '거',
#  38: '걱',
#  39: '건',
#  40: '걷',
#  41: '걸',
#  42: '걺',
#  43: '검',
#  44: '겁',
#  45: '것',
#  46: '겄',
#  47: '겅',
#  48: '겆',
#  49: '겉',
#  50: '겊',
#  51: '겋',
#  52: '게',
#  53: '겐',
#  54: '겔',
#  55: '겜',
#  56: '겝',
#  57: '겟',
#  58: '겠',
#  59: '겡',
#  60: '겨',
#  61: '격',
#  62: '겪',
#  63: '견',
#  64: '겯',
#  65: '결',
#  66: '겸',
#  67: '겹',
#  68: '겻',
#  69: '겼',
#  70: '경',
#  71: '곁',
#  72: '계',
#  73: '곈',
#  74: '곌',
#  75: '곕',
#  76: '곗',
#  77: '고',
#  78: '곡',
#  79: '곤',
#  80: '곧',
#  81: '골',
#  82: '곪',
#  83: '곬',
#  84: '곯',
#  85: '곰',
#  86: '곱',
#  87: '곳',
#  88: '공',
#  89: '곶',
#  90: '과',
#  91: '곽',
#  92: '관',
#  93: '괄',
#  94: '괆',
#  95: '괌',
#  96: '괍',
#  97: '괏',
#  98: '광',
#  99: '괘',
#  100: '괜',
#  101: '괠',
#  102: '괩',
#  103: '괬',
#  104: '괭',
#  105: '괴',
#  106: '괵',
#  107: '괸',
#  108: '괼',
#  109: '굄',
#  110: '굅',
#  111: '굇',
#  112: '굉',
#  113: '교',
#  114: '굔',
#  115: '굘',
#  116: '굡',
#  117: '굣',
#  118: '구',
#  119: '국',
#  120: '군',
#  121: '굳',
#  122: '굴',
#  123: '굵',
#  124: '굶',
#  125: '굻',
#  126: '굼',
#  127: '굽',
#  128: '굿',
#  129: '궁',
#  130: '궂',
#  131: '궈',
#  132: '궉',
#  133: '권',
#  134: '궐',
#  135: '궜',
#  136: '궝',
#  137: '궤',
#  138: '궷',
#  139: '귀',
#  140: '귁',
#  141: '귄',
#  142: '귈',
#  143: '귐',
#  144: '귑',
#  145: '귓',
#  146: '규',
#  147: '균',
#  148: '귤',
#  149: '그',
#  150: '극',
#  151: '근',
#  152: '귿',
#  153: '글',
#  154: '긁',
#  155: '금',
#  156: '급',
#  157: '긋',
#  158: '긍',
#  159: '긔',
#  160: '기',
#  161: '긱',
#  162: '긴',
#  163: '긷',
#  164: '길',
#  165: '긺',
#  166: '김',
#  167: '깁',
#  168: '깃',
#  169: '깅',
#  170: '깆',
#  171: '깊',
#  172: '까',
#  173: '깍',
#  174: '깎',
#  175: '깐',
#  176: '깔',
#  177: '깖',
#  178: '깜',
#  179: '깝',
#  180: '깟',
#  181: '깠',
#  182: '깡',
#  183: '깥',
#  184: '깨',
#  185: '깩',
#  186: '깬',
#  187: '깰',
#  188: '깸',
#  189: '깹',
#  190: '깻',
#  191: '깼',
#  192: '깽',
#  193: '꺄',
#  194: '꺅',
#  195: '꺌',
#  196: '꺼',
#  197: '꺽',
#  198: '꺾',
#  199: '껀',
#  200: '껄',
#  201: '껌',
#  202: '껍',
#  203: '껏',
#  204: '껐',
#  205: '껑',
#  206: '께',
#  207: '껙',
#  208: '껜',
#  209: '껨',
#  210: '껫',
#  211: '껭',
#  212: '껴',
#  213: '껸',
#  214: '껼',
#  215: '꼇',
#  216: '꼈',
#  217: '꼍',
#  218: '꼐',
#  219: '꼬',
#  220: '꼭',
#  221: '꼰',
#  222: '꼲',
#  223: '꼴',
#  224: '꼼',
#  225: '꼽',
#  226: '꼿',
#  227: '꽁',
#  228: '꽂',
#  229: '꽃',
#  230: '꽈',
#  231: '꽉',
#  232: '꽐',
#  233: '꽜',
#  234: '꽝',
#  235: '꽤',
#  236: '꽥',
#  237: '꽹',
#  238: '꾀',
#  239: '꾄',
#  240: '꾈',
#  241: '꾐',
#  242: '꾑',
#  243: '꾕',
#  244: '꾜',
#  245: '꾸',
#  246: '꾹',
#  247: '꾼',
#  248: '꿀',
#  249: '꿇',
#  250: '꿈',
#  251: '꿉',
#  252: '꿋',
#  253: '꿍',
#  254: '꿎',
#  255: '꿔',
#  256: '꿜',
#  257: '꿨',
#  258: '꿩',
#  259: '꿰',
#  260: '꿱',
#  261: '꿴',
#  262: '꿸',
#  263: '뀀',
#  264: '뀁',
#  265: '뀄',
#  266: '뀌',
#  267: '뀐',
#  268: '뀔',
#  269: '뀜',
#  270: '뀝',
#  271: '뀨',
#  272: '끄',
#  273: '끅',
#  274: '끈',
#  275: '끊',
#  276: '끌',
#  277: '끎',
#  278: '끓',
#  279: '끔',
#  280: '끕',
#  281: '끗',
#  282: '끙',
#  283: '끝',
#  284: '끼',
#  285: '끽',
#  286: '낀',
#  287: '낄',
#  288: '낌',
#  289: '낍',
#  290: '낏',
#  291: '낑',
#  292: '나',
#  293: '낙',
#  294: '낚',
#  295: '난',
#  296: '낟',
#  297: '날',
#  298: '낡',
#  299: '낢',
#  300: '남',
#  301: '납',
#  302: '낫',
#  303: '났',
#  304: '낭',
#  305: '낮',
#  306: '낯',
#  307: '낱',
#  308: '낳',
#  309: '내',
#  310: '낵',
#  311: '낸',
#  312: '낼',
#  313: '냄',
#  314: '냅',
#  315: '냇',
#  316: '냈',
#  317: '냉',
#  318: '냐',
#  319: '냑',
#  320: '냔',
#  321: '냘',
#  322: '냠',
#  323: '냥',
#  324: '너',
#  325: '넉',
#  326: '넋',
#  327: '넌',
#  328: '널',
#  329: '넒',
#  330: '넓',
#  331: '넘',
#  332: '넙',
#  333: '넛',
#  334: '넜',
#  335: '넝',
#  336: '넣',
#  337: '네',
#  338: '넥',
#  339: '넨',
#  340: '넬',
#  341: '넴',
#  342: '넵',
#  343: '넷',
#  344: '넸',
#  345: '넹',
#  346: '녀',
#  347: '녁',
#  348: '년',
#  349: '녈',
#  350: '념',
#  351: '녑',
#  352: '녔',
#  353: '녕',
#  354: '녘',
#  355: '녜',
#  356: '녠',
#  357: '노',
#  358: '녹',
#  359: '논',
#  360: '놀',
#  361: '놂',
#  362: '놈',
#  363: '놉',
#  364: '놋',
#  365: '농',
#  366: '높',
#  367: '놓',
#  368: '놔',
#  369: '놘',
#  370: '놜',
#  371: '놨',
#  372: '뇌',
#  373: '뇐',
#  374: '뇔',
#  375: '뇜',
#  376: '뇝',
#  377: '뇟',
#  378: '뇨',
#  379: '뇩',
#  380: '뇬',
#  381: '뇰',
#  382: '뇹',
#  383: '뇻',
#  384: '뇽',
#  385: '누',
#  386: '눅',
#  387: '눈',
#  388: '눋',
#  389: '눌',
#  390: '눔',
#  391: '눕',
#  392: '눗',
#  393: '눙',
#  394: '눠',
#  395: '눴',
#  396: '눼',
#  397: '뉘',
#  398: '뉜',
#  399: '뉠',
#  400: '뉨',
#  401: '뉩',
#  402: '뉴',
#  403: '뉵',
#  404: '뉼',
#  405: '늄',
#  406: '늅',
#  407: '늉',
#  408: '느',
#  409: '늑',
#  410: '는',
#  411: '늘',
#  412: '늙',
#  413: '늚',
#  414: '늠',
#  415: '늡',
#  416: '늣',
#  417: '능',
#  418: '늦',
#  419: '늪',
#  420: '늬',
#  421: '늰',
#  422: '늴',
#  423: '니',
#  424: '닉',
#  425: '닌',
#  426: '닐',
#  427: '닒',
#  428: '님',
#  429: '닙',
#  430: '닛',
#  431: '닝',
#  432: '닢',
#  433: '다',
#  434: '닥',
#  435: '닦',
#  436: '단',
#  437: '닫',
#  438: '달',
#  439: '닭',
#  440: '닮',
#  441: '닯',
#  442: '닳',
#  443: '담',
#  444: '답',
#  445: '닷',
#  446: '닸',
#  447: '당',
#  448: '닺',
#  449: '닻',
#  450: '닿',
#  451: '대',
#  452: '댁',
#  453: '댄',
#  454: '댈',
#  455: '댐',
#  456: '댑',
#  457: '댓',
#  458: '댔',
#  459: '댕',
#  460: '댜',
#  461: '더',
#  462: '덕',
#  463: '덖',
#  464: '던',
#  465: '덛',
#  466: '덜',
#  467: '덞',
#  468: '덟',
#  469: '덤',
#  470: '덥',
#  471: '덧',
#  472: '덩',
#  473: '덫',
#  474: '덮',
#  475: '데',
#  476: '덱',
#  477: '덴',
#  478: '델',
#  479: '뎀',
#  480: '뎁',
#  481: '뎃',
#  482: '뎄',
#  483: '뎅',
#  484: '뎌',
#  485: '뎐',
#  486: '뎔',
#  487: '뎠',
#  488: '뎡',
#  489: '뎨',
#  490: '뎬',
#  491: '도',
#  492: '독',
#  493: '돈',
#  494: '돋',
#  495: '돌',
#  496: '돎',
#  497: '돐',
#  498: '돔',
#  499: '돕',
#  500: '돗',
#  501: '동',
#  502: '돛',
#  503: '돝',
#  504: '돠',
#  505: '돤',
#  506: '돨',
#  507: '돼',
#  508: '됐',
#  509: '되',
#  510: '된',
#  511: '될',
#  512: '됨',
#  513: '됩',
#  514: '됫',
#  515: '됴',
#  516: '두',
#  517: '둑',
#  518: '둔',
#  519: '둘',
#  520: '둠',
#  521: '둡',
#  522: '둣',
#  523: '둥',
#  524: '둬',
#  525: '뒀',
#  526: '뒈',
#  527: '뒝',
#  528: '뒤',
#  529: '뒨',
#  530: '뒬',
#  531: '뒵',
#  532: '뒷',
#  533: '뒹',
#  534: '듀',
#  535: '듄',
#  536: '듈',
#  537: '듐',
#  538: '듕',
#  539: '드',
#  540: '득',
#  541: '든',
#  542: '듣',
#  543: '들',
#  544: '듦',
#  545: '듬',
#  546: '듭',
#  547: '듯',
#  548: '등',
#  549: '듸',
#  550: '디',
#  551: '딕',
#  552: '딘',
#  553: '딛',
#  554: '딜',
#  555: '딤',
#  556: '딥',
#  557: '딧',
#  558: '딨',
#  559: '딩',
#  560: '딪',
#  561: '따',
#  562: '딱',
#  563: '딴',
#  564: '딸',
#  565: '땀',
#  566: '땁',
#  567: '땃',
#  568: '땄',
#  569: '땅',
#  570: '땋',
#  571: '때',
#  572: '땍',
#  573: '땐',
#  574: '땔',
#  575: '땜',
#  576: '땝',
#  577: '땟',
#  578: '땠',
#  579: '땡',
#  580: '떠',
#  581: '떡',
#  582: '떤',
#  583: '떨',
#  584: '떪',
#  585: '떫',
#  586: '떰',
#  587: '떱',
#  588: '떳',
#  589: '떴',
#  590: '떵',
#  591: '떻',
#  592: '떼',
#  593: '떽',
#  594: '뗀',
#  595: '뗄',
#  596: '뗌',
#  597: '뗍',
#  598: '뗏',
#  599: '뗐',
#  600: '뗑',
#  601: '뗘',
#  602: '뗬',
#  603: '또',
#  604: '똑',
#  605: '똔',
#  606: '똘',
#  607: '똥',
#  608: '똬',
#  609: '똴',
#  610: '뙈',
#  611: '뙤',
#  612: '뙨',
#  613: '뚜',
#  614: '뚝',
#  615: '뚤',
#  616: '뚫',
#  617: '뚬',
#  618: '뚱',
#  619: '뛔',
#  620: '뛰',
#  621: '뛴',
#  622: '뛸',
#  623: '뜀',
#  624: '뜁',
#  625: '뜅',
#  626: '뜨',
#  627: '뜩',
#  628: '뜬',
#  629: '뜯',
#  630: '뜰',
#  631: '뜸',
#  632: '뜹',
#  633: '뜻',
#  634: '띄',
#  635: '띈',
#  636: '띌',
#  637: '띔',
#  638: '띕',
#  639: '띠',
#  640: '띤',
#  641: '띨',
#  642: '띰',
#  643: '띱',
#  644: '띳',
#  645: '띵',
#  646: '라',
#  647: '락',
#  648: '란',
#  649: '랄',
#  650: '람',
#  651: '랍',
#  652: '랏',
#  653: '랐',
#  654: '랑',
#  655: '랒',
#  656: '랖',
#  657: '랗',
#  658: '래',
#  659: '랙',
#  660: '랜',
#  661: '랠',
#  662: '램',
#  663: '랩',
#  664: '랫',
#  665: '랬',
#  666: '랭',
#  667: '랴',
#  668: '략',
#  669: '랸',
#  670: '럇',
#  671: '량',
#  672: '러',
#  673: '럭',
#  674: '런',
#  675: '럴',
#  676: '럼',
#  677: '럽',
#  678: '럿',
#  679: '렀',
#  680: '렁',
#  681: '렇',
#  682: '레',
#  683: '렉',
#  684: '렌',
#  685: '렐',
#  686: '렘',
#  687: '렙',
#  688: '렛',
#  689: '렝',
#  690: '려',
#  691: '력',
#  692: '련',
#  693: '렬',
#  694: '렴',
#  695: '렵',
#  696: '렷',
#  697: '렸',
#  698: '령',
#  699: '례',
#  700: '롄',
#  701: '롑',
#  702: '롓',
#  703: '로',
#  704: '록',
#  705: '론',
#  706: '롤',
#  707: '롬',
#  708: '롭',
#  709: '롯',
#  710: '롱',
#  711: '롸',
#  712: '롼',
#  713: '뢍',
#  714: '뢨',
#  715: '뢰',
#  716: '뢴',
#  717: '뢸',
#  718: '룀',
#  719: '룁',
#  720: '룃',
#  721: '룅',
#  722: '료',
#  723: '룐',
#  724: '룔',
#  725: '룝',
#  726: '룟',
#  727: '룡',
#  728: '루',
#  729: '룩',
#  730: '룬',
#  731: '룰',
#  732: '룸',
#  733: '룹',
#  734: '룻',
#  735: '룽',
#  736: '뤄',
#  737: '뤘',
#  738: '뤠',
#  739: '뤼',
#  740: '뤽',
#  741: '륀',
#  742: '륄',
#  743: '륌',
#  744: '륏',
#  745: '륑',
#  746: '류',
#  747: '륙',
#  748: '륜',
#  749: '률',
#  750: '륨',
#  751: '륩',
#  752: '륫',
#  753: '륭',
#  754: '르',
#  755: '륵',
#  756: '른',
#  757: '를',
#  758: '름',
#  759: '릅',
#  760: '릇',
#  761: '릉',
#  762: '릊',
#  763: '릍',
#  764: '릎',
#  765: '리',
#  766: '릭',
#  767: '린',
#  768: '릴',
#  769: '림',
#  770: '립',
#  771: '릿',
#  772: '링',
#  773: '마',
#  774: '막',
#  775: '만',
#  776: '많',
#  777: '맏',
#  778: '말',
#  779: '맑',
#  780: '맒',
#  781: '맘',
#  782: '맙',
#  783: '맛',
#  784: '망',
#  785: '맞',
#  786: '맡',
#  787: '맣',
#  788: '매',
#  789: '맥',
#  790: '맨',
#  791: '맬',
#  792: '맴',
#  793: '맵',
#  794: '맷',
#  795: '맸',
#  796: '맹',
#  797: '맺',
#  798: '먀',
#  799: '먁',
#  800: '먈',
#  801: '먕',
#  802: '머',
#  803: '먹',
#  804: '먼',
#  805: '멀',
#  806: '멂',
#  807: '멈',
#  808: '멉',
#  809: '멋',
#  810: '멍',
#  811: '멎',
#  812: '멓',
#  813: '메',
#  814: '멕',
#  815: '멘',
#  816: '멜',
#  817: '멤',
#  818: '멥',
#  819: '멧',
#  820: '멨',
#  821: '멩',
#  822: '며',
#  823: '멱',
#  824: '면',
#  825: '멸',
#  826: '몃',
#  827: '몄',
#  828: '명',
#  829: '몇',
#  830: '몌',
#  831: '모',
#  832: '목',
#  833: '몫',
#  834: '몬',
#  835: '몰',
#  836: '몲',
#  837: '몸',
#  838: '몹',
#  839: '못',
#  840: '몽',
#  841: '뫄',
#  842: '뫈',
#  843: '뫘',
#  844: '뫙',
#  845: '뫼',
#  846: '묀',
#  847: '묄',
#  848: '묍',
#  849: '묏',
#  850: '묑',
#  851: '묘',
#  852: '묜',
#  853: '묠',
#  854: '묩',
#  855: '묫',
#  856: '무',
#  857: '묵',
#  858: '묶',
#  859: '문',
#  860: '묻',
#  861: '물',
#  862: '묽',
#  863: '묾',
#  864: '뭄',
#  865: '뭅',
#  866: '뭇',
#  867: '뭉',
#  868: '뭍',
#  869: '뭏',
#  870: '뭐',
#  871: '뭔',
#  872: '뭘',
#  873: '뭡',
#  874: '뭣',
#  875: '뭬',
#  876: '뮈',
#  877: '뮌',
#  878: '뮐',
#  879: '뮤',
#  880: '뮨',
#  881: '뮬',
#  882: '뮴',
#  883: '뮷',
#  884: '므',
#  885: '믄',
#  886: '믈',
#  887: '믐',
#  888: '믓',
#  889: '미',
#  890: '믹',
#  891: '민',
#  892: '믿',
#  893: '밀',
#  894: '밂',
#  895: '밈',
#  896: '밉',
#  897: '밋',
#  898: '밌',
#  899: '밍',
#  900: '및',
#  901: '밑',
#  902: '바',
#  903: '박',
#  904: '밖',
#  905: '밗',
#  906: '반',
#  907: '받',
#  908: '발',
#  909: '밝',
#  910: '밞',
#  911: '밟',
#  912: '밤',
#  913: '밥',
#  914: '밧',
#  915: '방',
#  916: '밭',
#  917: '배',
#  918: '백',
#  919: '밴',
#  920: '밸',
#  921: '뱀',
#  922: '뱁',
#  923: '뱃',
#  924: '뱄',
#  925: '뱅',
#  926: '뱉',
#  927: '뱌',
#  928: '뱍',
#  929: '뱐',
#  930: '뱝',
#  931: '버',
#  932: '벅',
#  933: '번',
#  934: '벋',
#  935: '벌',
#  936: '벎',
#  937: '범',
#  938: '법',
#  939: '벗',
#  940: '벙',
#  941: '벚',
#  942: '베',
#  943: '벡',
#  944: '벤',
#  945: '벧',
#  946: '벨',
#  947: '벰',
#  948: '벱',
#  949: '벳',
#  950: '벴',
#  951: '벵',
#  952: '벼',
#  953: '벽',
#  954: '변',
#  955: '별',
#  956: '볍',
#  957: '볏',
#  958: '볐',
#  959: '병',
#  960: '볕',
#  961: '볘',
#  962: '볜',
#  963: '보',
#  964: '복',
#  965: '볶',
#  966: '본',
#  967: '볼',
#  968: '봄',
#  969: '봅',
#  970: '봇',
#  971: '봉',
#  972: '봐',
#  973: '봔',
#  974: '봤',
#  975: '봬',
#  976: '뵀',
#  977: '뵈',
#  978: '뵉',
#  979: '뵌',
#  980: '뵐',
#  981: '뵘',
#  982: '뵙',
#  983: '뵤',
#  984: '뵨',
#  985: '부',
#  986: '북',
#  987: '분',
#  988: '붇',
#  989: '불',
#  990: '붉',
#  991: '붊',
#  992: '붐',
#  993: '붑',
#  994: '붓',
#  995: '붕',
#  996: '붙',
#  997: '붚',
#  998: '붜',
#  999: '붤',
#  ...}

# %%
char2idx = {v: k for k, v in idx2char.items()}
char2idx
# Out:
# {'-': 0,
#  '가': 1,
#  '각': 2,
#  '간': 3,
#  '갇': 4,
#  '갈': 5,
#  '갉': 6,
#  '갊': 7,
#  '감': 8,
#  '갑': 9,
#  '값': 10,
#  '갓': 11,
#  '갔': 12,
#  '강': 13,
#  '갖': 14,
#  '갗': 15,
#  '같': 16,
#  '갚': 17,
#  '갛': 18,
#  '개': 19,
#  '객': 20,
#  '갠': 21,
#  '갤': 22,
#  '갬': 23,
#  '갭': 24,
#  '갯': 25,
#  '갰': 26,
#  '갱': 27,
#  '갸': 28,
#  '갹': 29,
#  '갼': 30,
#  '걀': 31,
#  '걋': 32,
#  '걍': 33,
#  '걔': 34,
#  '걘': 35,
#  '걜': 36,
#  '거': 37,
#  '걱': 38,
#  '건': 39,
#  '걷': 40,
#  '걸': 41,
#  '걺': 42,
#  '검': 43,
#  '겁': 44,
#  '것': 45,
#  '겄': 46,
#  '겅': 47,
#  '겆': 48,
#  '겉': 49,
#  '겊': 50,
#  '겋': 51,
#  '게': 52,
#  '겐': 53,
#  '겔': 54,
#  '겜': 55,
#  '겝': 56,
#  '겟': 57,
#  '겠': 58,
#  '겡': 59,
#  '겨': 60,
#  '격': 61,
#  '겪': 62,
#  '견': 63,
#  '겯': 64,
#  '결': 65,
#  '겸': 66,
#  '겹': 67,
#  '겻': 68,
#  '겼': 69,
#  '경': 70,
#  '곁': 71,
#  '계': 72,
#  '곈': 73,
#  '곌': 74,
#  '곕': 75,
#  '곗': 76,
#  '고': 77,
#  '곡': 78,
#  '곤': 79,
#  '곧': 80,
#  '골': 81,
#  '곪': 82,
#  '곬': 83,
#  '곯': 84,
#  '곰': 85,
#  '곱': 86,
#  '곳': 87,
#  '공': 88,
#  '곶': 89,
#  '과': 90,
#  '곽': 91,
#  '관': 92,
#  '괄': 93,
#  '괆': 94,
#  '괌': 95,
#  '괍': 96,
#  '괏': 97,
#  '광': 98,
#  '괘': 99,
#  '괜': 100,
#  '괠': 101,
#  '괩': 102,
#  '괬': 103,
#  '괭': 104,
#  '괴': 105,
#  '괵': 106,
#  '괸': 107,
#  '괼': 108,
#  '굄': 109,
#  '굅': 110,
#  '굇': 111,
#  '굉': 112,
#  '교': 113,
#  '굔': 114,
#  '굘': 115,
#  '굡': 116,
#  '굣': 117,
#  '구': 118,
#  '국': 119,
#  '군': 120,
#  '굳': 121,
#  '굴': 122,
#  '굵': 123,
#  '굶': 124,
#  '굻': 125,
#  '굼': 126,
#  '굽': 127,
#  '굿': 128,
#  '궁': 129,
#  '궂': 130,
#  '궈': 131,
#  '궉': 132,
#  '권': 133,
#  '궐': 134,
#  '궜': 135,
#  '궝': 136,
#  '궤': 137,
#  '궷': 138,
#  '귀': 139,
#  '귁': 140,
#  '귄': 141,
#  '귈': 142,
#  '귐': 143,
#  '귑': 144,
#  '귓': 145,
#  '규': 146,
#  '균': 147,
#  '귤': 148,
#  '그': 149,
#  '극': 150,
#  '근': 151,
#  '귿': 152,
#  '글': 153,
#  '긁': 154,
#  '금': 155,
#  '급': 156,
#  '긋': 157,
#  '긍': 158,
#  '긔': 159,
#  '기': 160,
#  '긱': 161,
#  '긴': 162,
#  '긷': 163,
#  '길': 164,
#  '긺': 165,
#  '김': 166,
#  '깁': 167,
#  '깃': 168,
#  '깅': 169,
#  '깆': 170,
#  '깊': 171,
#  '까': 172,
#  '깍': 173,
#  '깎': 174,
#  '깐': 175,
#  '깔': 176,
#  '깖': 177,
#  '깜': 178,
#  '깝': 179,
#  '깟': 180,
#  '깠': 181,
#  '깡': 182,
#  '깥': 183,
#  '깨': 184,
#  '깩': 185,
#  '깬': 186,
#  '깰': 187,
#  '깸': 188,
#  '깹': 189,
#  '깻': 190,
#  '깼': 191,
#  '깽': 192,
#  '꺄': 193,
#  '꺅': 194,
#  '꺌': 195,
#  '꺼': 196,
#  '꺽': 197,
#  '꺾': 198,
#  '껀': 199,
#  '껄': 200,
#  '껌': 201,
#  '껍': 202,
#  '껏': 203,
#  '껐': 204,
#  '껑': 205,
#  '께': 206,
#  '껙': 207,
#  '껜': 208,
#  '껨': 209,
#  '껫': 210,
#  '껭': 211,
#  '껴': 212,
#  '껸': 213,
#  '껼': 214,
#  '꼇': 215,
#  '꼈': 216,
#  '꼍': 217,
#  '꼐': 218,
#  '꼬': 219,
#  '꼭': 220,
#  '꼰': 221,
#  '꼲': 222,
#  '꼴': 223,
#  '꼼': 224,
#  '꼽': 225,
#  '꼿': 226,
#  '꽁': 227,
#  '꽂': 228,
#  '꽃': 229,
#  '꽈': 230,
#  '꽉': 231,
#  '꽐': 232,
#  '꽜': 233,
#  '꽝': 234,
#  '꽤': 235,
#  '꽥': 236,
#  '꽹': 237,
#  '꾀': 238,
#  '꾄': 239,
#  '꾈': 240,
#  '꾐': 241,
#  '꾑': 242,
#  '꾕': 243,
#  '꾜': 244,
#  '꾸': 245,
#  '꾹': 246,
#  '꾼': 247,
#  '꿀': 248,
#  '꿇': 249,
#  '꿈': 250,
#  '꿉': 251,
#  '꿋': 252,
#  '꿍': 253,
#  '꿎': 254,
#  '꿔': 255,
#  '꿜': 256,
#  '꿨': 257,
#  '꿩': 258,
#  '꿰': 259,
#  '꿱': 260,
#  '꿴': 261,
#  '꿸': 262,
#  '뀀': 263,
#  '뀁': 264,
#  '뀄': 265,
#  '뀌': 266,
#  '뀐': 267,
#  '뀔': 268,
#  '뀜': 269,
#  '뀝': 270,
#  '뀨': 271,
#  '끄': 272,
#  '끅': 273,
#  '끈': 274,
#  '끊': 275,
#  '끌': 276,
#  '끎': 277,
#  '끓': 278,
#  '끔': 279,
#  '끕': 280,
#  '끗': 281,
#  '끙': 282,
#  '끝': 283,
#  '끼': 284,
#  '끽': 285,
#  '낀': 286,
#  '낄': 287,
#  '낌': 288,
#  '낍': 289,
#  '낏': 290,
#  '낑': 291,
#  '나': 292,
#  '낙': 293,
#  '낚': 294,
#  '난': 295,
#  '낟': 296,
#  '날': 297,
#  '낡': 298,
#  '낢': 299,
#  '남': 300,
#  '납': 301,
#  '낫': 302,
#  '났': 303,
#  '낭': 304,
#  '낮': 305,
#  '낯': 306,
#  '낱': 307,
#  '낳': 308,
#  '내': 309,
#  '낵': 310,
#  '낸': 311,
#  '낼': 312,
#  '냄': 313,
#  '냅': 314,
#  '냇': 315,
#  '냈': 316,
#  '냉': 317,
#  '냐': 318,
#  '냑': 319,
#  '냔': 320,
#  '냘': 321,
#  '냠': 322,
#  '냥': 323,
#  '너': 324,
#  '넉': 325,
#  '넋': 326,
#  '넌': 327,
#  '널': 328,
#  '넒': 329,
#  '넓': 330,
#  '넘': 331,
#  '넙': 332,
#  '넛': 333,
#  '넜': 334,
#  '넝': 335,
#  '넣': 336,
#  '네': 337,
#  '넥': 338,
#  '넨': 339,
#  '넬': 340,
#  '넴': 341,
#  '넵': 342,
#  '넷': 343,
#  '넸': 344,
#  '넹': 345,
#  '녀': 346,
#  '녁': 347,
#  '년': 348,
#  '녈': 349,
#  '념': 350,
#  '녑': 351,
#  '녔': 352,
#  '녕': 353,
#  '녘': 354,
#  '녜': 355,
#  '녠': 356,
#  '노': 357,
#  '녹': 358,
#  '논': 359,
#  '놀': 360,
#  '놂': 361,
#  '놈': 362,
#  '놉': 363,
#  '놋': 364,
#  '농': 365,
#  '높': 366,
#  '놓': 367,
#  '놔': 368,
#  '놘': 369,
#  '놜': 370,
#  '놨': 371,
#  '뇌': 372,
#  '뇐': 373,
#  '뇔': 374,
#  '뇜': 375,
#  '뇝': 376,
#  '뇟': 377,
#  '뇨': 378,
#  '뇩': 379,
#  '뇬': 380,
#  '뇰': 381,
#  '뇹': 382,
#  '뇻': 383,
#  '뇽': 384,
#  '누': 385,
#  '눅': 386,
#  '눈': 387,
#  '눋': 388,
#  '눌': 389,
#  '눔': 390,
#  '눕': 391,
#  '눗': 392,
#  '눙': 393,
#  '눠': 394,
#  '눴': 395,
#  '눼': 396,
#  '뉘': 397,
#  '뉜': 398,
#  '뉠': 399,
#  '뉨': 400,
#  '뉩': 401,
#  '뉴': 402,
#  '뉵': 403,
#  '뉼': 404,
#  '늄': 405,
#  '늅': 406,
#  '늉': 407,
#  '느': 408,
#  '늑': 409,
#  '는': 410,
#  '늘': 411,
#  '늙': 412,
#  '늚': 413,
#  '늠': 414,
#  '늡': 415,
#  '늣': 416,
#  '능': 417,
#  '늦': 418,
#  '늪': 419,
#  '늬': 420,
#  '늰': 421,
#  '늴': 422,
#  '니': 423,
#  '닉': 424,
#  '닌': 425,
#  '닐': 426,
#  '닒': 427,
#  '님': 428,
#  '닙': 429,
#  '닛': 430,
#  '닝': 431,
#  '닢': 432,
#  '다': 433,
#  '닥': 434,
#  '닦': 435,
#  '단': 436,
#  '닫': 437,
#  '달': 438,
#  '닭': 439,
#  '닮': 440,
#  '닯': 441,
#  '닳': 442,
#  '담': 443,
#  '답': 444,
#  '닷': 445,
#  '닸': 446,
#  '당': 447,
#  '닺': 448,
#  '닻': 449,
#  '닿': 450,
#  '대': 451,
#  '댁': 452,
#  '댄': 453,
#  '댈': 454,
#  '댐': 455,
#  '댑': 456,
#  '댓': 457,
#  '댔': 458,
#  '댕': 459,
#  '댜': 460,
#  '더': 461,
#  '덕': 462,
#  '덖': 463,
#  '던': 464,
#  '덛': 465,
#  '덜': 466,
#  '덞': 467,
#  '덟': 468,
#  '덤': 469,
#  '덥': 470,
#  '덧': 471,
#  '덩': 472,
#  '덫': 473,
#  '덮': 474,
#  '데': 475,
#  '덱': 476,
#  '덴': 477,
#  '델': 478,
#  '뎀': 479,
#  '뎁': 480,
#  '뎃': 481,
#  '뎄': 482,
#  '뎅': 483,
#  '뎌': 484,
#  '뎐': 485,
#  '뎔': 486,
#  '뎠': 487,
#  '뎡': 488,
#  '뎨': 489,
#  '뎬': 490,
#  '도': 491,
#  '독': 492,
#  '돈': 493,
#  '돋': 494,
#  '돌': 495,
#  '돎': 496,
#  '돐': 497,
#  '돔': 498,
#  '돕': 499,
#  '돗': 500,
#  '동': 501,
#  '돛': 502,
#  '돝': 503,
#  '돠': 504,
#  '돤': 505,
#  '돨': 506,
#  '돼': 507,
#  '됐': 508,
#  '되': 509,
#  '된': 510,
#  '될': 511,
#  '됨': 512,
#  '됩': 513,
#  '됫': 514,
#  '됴': 515,
#  '두': 516,
#  '둑': 517,
#  '둔': 518,
#  '둘': 519,
#  '둠': 520,
#  '둡': 521,
#  '둣': 522,
#  '둥': 523,
#  '둬': 524,
#  '뒀': 525,
#  '뒈': 526,
#  '뒝': 527,
#  '뒤': 528,
#  '뒨': 529,
#  '뒬': 530,
#  '뒵': 531,
#  '뒷': 532,
#  '뒹': 533,
#  '듀': 534,
#  '듄': 535,
#  '듈': 536,
#  '듐': 537,
#  '듕': 538,
#  '드': 539,
#  '득': 540,
#  '든': 541,
#  '듣': 542,
#  '들': 543,
#  '듦': 544,
#  '듬': 545,
#  '듭': 546,
#  '듯': 547,
#  '등': 548,
#  '듸': 549,
#  '디': 550,
#  '딕': 551,
#  '딘': 552,
#  '딛': 553,
#  '딜': 554,
#  '딤': 555,
#  '딥': 556,
#  '딧': 557,
#  '딨': 558,
#  '딩': 559,
#  '딪': 560,
#  '따': 561,
#  '딱': 562,
#  '딴': 563,
#  '딸': 564,
#  '땀': 565,
#  '땁': 566,
#  '땃': 567,
#  '땄': 568,
#  '땅': 569,
#  '땋': 570,
#  '때': 571,
#  '땍': 572,
#  '땐': 573,
#  '땔': 574,
#  '땜': 575,
#  '땝': 576,
#  '땟': 577,
#  '땠': 578,
#  '땡': 579,
#  '떠': 580,
#  '떡': 581,
#  '떤': 582,
#  '떨': 583,
#  '떪': 584,
#  '떫': 585,
#  '떰': 586,
#  '떱': 587,
#  '떳': 588,
#  '떴': 589,
#  '떵': 590,
#  '떻': 591,
#  '떼': 592,
#  '떽': 593,
#  '뗀': 594,
#  '뗄': 595,
#  '뗌': 596,
#  '뗍': 597,
#  '뗏': 598,
#  '뗐': 599,
#  '뗑': 600,
#  '뗘': 601,
#  '뗬': 602,
#  '또': 603,
#  '똑': 604,
#  '똔': 605,
#  '똘': 606,
#  '똥': 607,
#  '똬': 608,
#  '똴': 609,
#  '뙈': 610,
#  '뙤': 611,
#  '뙨': 612,
#  '뚜': 613,
#  '뚝': 614,
#  '뚤': 615,
#  '뚫': 616,
#  '뚬': 617,
#  '뚱': 618,
#  '뛔': 619,
#  '뛰': 620,
#  '뛴': 621,
#  '뛸': 622,
#  '뜀': 623,
#  '뜁': 624,
#  '뜅': 625,
#  '뜨': 626,
#  '뜩': 627,
#  '뜬': 628,
#  '뜯': 629,
#  '뜰': 630,
#  '뜸': 631,
#  '뜹': 632,
#  '뜻': 633,
#  '띄': 634,
#  '띈': 635,
#  '띌': 636,
#  '띔': 637,
#  '띕': 638,
#  '띠': 639,
#  '띤': 640,
#  '띨': 641,
#  '띰': 642,
#  '띱': 643,
#  '띳': 644,
#  '띵': 645,
#  '라': 646,
#  '락': 647,
#  '란': 648,
#  '랄': 649,
#  '람': 650,
#  '랍': 651,
#  '랏': 652,
#  '랐': 653,
#  '랑': 654,
#  '랒': 655,
#  '랖': 656,
#  '랗': 657,
#  '래': 658,
#  '랙': 659,
#  '랜': 660,
#  '랠': 661,
#  '램': 662,
#  '랩': 663,
#  '랫': 664,
#  '랬': 665,
#  '랭': 666,
#  '랴': 667,
#  '략': 668,
#  '랸': 669,
#  '럇': 670,
#  '량': 671,
#  '러': 672,
#  '럭': 673,
#  '런': 674,
#  '럴': 675,
#  '럼': 676,
#  '럽': 677,
#  '럿': 678,
#  '렀': 679,
#  '렁': 680,
#  '렇': 681,
#  '레': 682,
#  '렉': 683,
#  '렌': 684,
#  '렐': 685,
#  '렘': 686,
#  '렙': 687,
#  '렛': 688,
#  '렝': 689,
#  '려': 690,
#  '력': 691,
#  '련': 692,
#  '렬': 693,
#  '렴': 694,
#  '렵': 695,
#  '렷': 696,
#  '렸': 697,
#  '령': 698,
#  '례': 699,
#  '롄': 700,
#  '롑': 701,
#  '롓': 702,
#  '로': 703,
#  '록': 704,
#  '론': 705,
#  '롤': 706,
#  '롬': 707,
#  '롭': 708,
#  '롯': 709,
#  '롱': 710,
#  '롸': 711,
#  '롼': 712,
#  '뢍': 713,
#  '뢨': 714,
#  '뢰': 715,
#  '뢴': 716,
#  '뢸': 717,
#  '룀': 718,
#  '룁': 719,
#  '룃': 720,
#  '룅': 721,
#  '료': 722,
#  '룐': 723,
#  '룔': 724,
#  '룝': 725,
#  '룟': 726,
#  '룡': 727,
#  '루': 728,
#  '룩': 729,
#  '룬': 730,
#  '룰': 731,
#  '룸': 732,
#  '룹': 733,
#  '룻': 734,
#  '룽': 735,
#  '뤄': 736,
#  '뤘': 737,
#  '뤠': 738,
#  '뤼': 739,
#  '뤽': 740,
#  '륀': 741,
#  '륄': 742,
#  '륌': 743,
#  '륏': 744,
#  '륑': 745,
#  '류': 746,
#  '륙': 747,
#  '륜': 748,
#  '률': 749,
#  '륨': 750,
#  '륩': 751,
#  '륫': 752,
#  '륭': 753,
#  '르': 754,
#  '륵': 755,
#  '른': 756,
#  '를': 757,
#  '름': 758,
#  '릅': 759,
#  '릇': 760,
#  '릉': 761,
#  '릊': 762,
#  '릍': 763,
#  '릎': 764,
#  '리': 765,
#  '릭': 766,
#  '린': 767,
#  '릴': 768,
#  '림': 769,
#  '립': 770,
#  '릿': 771,
#  '링': 772,
#  '마': 773,
#  '막': 774,
#  '만': 775,
#  '많': 776,
#  '맏': 777,
#  '말': 778,
#  '맑': 779,
#  '맒': 780,
#  '맘': 781,
#  '맙': 782,
#  '맛': 783,
#  '망': 784,
#  '맞': 785,
#  '맡': 786,
#  '맣': 787,
#  '매': 788,
#  '맥': 789,
#  '맨': 790,
#  '맬': 791,
#  '맴': 792,
#  '맵': 793,
#  '맷': 794,
#  '맸': 795,
#  '맹': 796,
#  '맺': 797,
#  '먀': 798,
#  '먁': 799,
#  '먈': 800,
#  '먕': 801,
#  '머': 802,
#  '먹': 803,
#  '먼': 804,
#  '멀': 805,
#  '멂': 806,
#  '멈': 807,
#  '멉': 808,
#  '멋': 809,
#  '멍': 810,
#  '멎': 811,
#  '멓': 812,
#  '메': 813,
#  '멕': 814,
#  '멘': 815,
#  '멜': 816,
#  '멤': 817,
#  '멥': 818,
#  '멧': 819,
#  '멨': 820,
#  '멩': 821,
#  '며': 822,
#  '멱': 823,
#  '면': 824,
#  '멸': 825,
#  '몃': 826,
#  '몄': 827,
#  '명': 828,
#  '몇': 829,
#  '몌': 830,
#  '모': 831,
#  '목': 832,
#  '몫': 833,
#  '몬': 834,
#  '몰': 835,
#  '몲': 836,
#  '몸': 837,
#  '몹': 838,
#  '못': 839,
#  '몽': 840,
#  '뫄': 841,
#  '뫈': 842,
#  '뫘': 843,
#  '뫙': 844,
#  '뫼': 845,
#  '묀': 846,
#  '묄': 847,
#  '묍': 848,
#  '묏': 849,
#  '묑': 850,
#  '묘': 851,
#  '묜': 852,
#  '묠': 853,
#  '묩': 854,
#  '묫': 855,
#  '무': 856,
#  '묵': 857,
#  '묶': 858,
#  '문': 859,
#  '묻': 860,
#  '물': 861,
#  '묽': 862,
#  '묾': 863,
#  '뭄': 864,
#  '뭅': 865,
#  '뭇': 866,
#  '뭉': 867,
#  '뭍': 868,
#  '뭏': 869,
#  '뭐': 870,
#  '뭔': 871,
#  '뭘': 872,
#  '뭡': 873,
#  '뭣': 874,
#  '뭬': 875,
#  '뮈': 876,
#  '뮌': 877,
#  '뮐': 878,
#  '뮤': 879,
#  '뮨': 880,
#  '뮬': 881,
#  '뮴': 882,
#  '뮷': 883,
#  '므': 884,
#  '믄': 885,
#  '믈': 886,
#  '믐': 887,
#  '믓': 888,
#  '미': 889,
#  '믹': 890,
#  '민': 891,
#  '믿': 892,
#  '밀': 893,
#  '밂': 894,
#  '밈': 895,
#  '밉': 896,
#  '밋': 897,
#  '밌': 898,
#  '밍': 899,
#  '및': 900,
#  '밑': 901,
#  '바': 902,
#  '박': 903,
#  '밖': 904,
#  '밗': 905,
#  '반': 906,
#  '받': 907,
#  '발': 908,
#  '밝': 909,
#  '밞': 910,
#  '밟': 911,
#  '밤': 912,
#  '밥': 913,
#  '밧': 914,
#  '방': 915,
#  '밭': 916,
#  '배': 917,
#  '백': 918,
#  '밴': 919,
#  '밸': 920,
#  '뱀': 921,
#  '뱁': 922,
#  '뱃': 923,
#  '뱄': 924,
#  '뱅': 925,
#  '뱉': 926,
#  '뱌': 927,
#  '뱍': 928,
#  '뱐': 929,
#  '뱝': 930,
#  '버': 931,
#  '벅': 932,
#  '번': 933,
#  '벋': 934,
#  '벌': 935,
#  '벎': 936,
#  '범': 937,
#  '법': 938,
#  '벗': 939,
#  '벙': 940,
#  '벚': 941,
#  '베': 942,
#  '벡': 943,
#  '벤': 944,
#  '벧': 945,
#  '벨': 946,
#  '벰': 947,
#  '벱': 948,
#  '벳': 949,
#  '벴': 950,
#  '벵': 951,
#  '벼': 952,
#  '벽': 953,
#  '변': 954,
#  '별': 955,
#  '볍': 956,
#  '볏': 957,
#  '볐': 958,
#  '병': 959,
#  '볕': 960,
#  '볘': 961,
#  '볜': 962,
#  '보': 963,
#  '복': 964,
#  '볶': 965,
#  '본': 966,
#  '볼': 967,
#  '봄': 968,
#  '봅': 969,
#  '봇': 970,
#  '봉': 971,
#  '봐': 972,
#  '봔': 973,
#  '봤': 974,
#  '봬': 975,
#  '뵀': 976,
#  '뵈': 977,
#  '뵉': 978,
#  '뵌': 979,
#  '뵐': 980,
#  '뵘': 981,
#  '뵙': 982,
#  '뵤': 983,
#  '뵨': 984,
#  '부': 985,
#  '북': 986,
#  '분': 987,
#  '붇': 988,
#  '불': 989,
#  '붉': 990,
#  '붊': 991,
#  '붐': 992,
#  '붑': 993,
#  '붓': 994,
#  '붕': 995,
#  '붙': 996,
#  '붚': 997,
#  '붜': 998,
#  '붤': 999,
#  ...}

# %%
vocabulary = ["-"] + letters
print(len(vocabulary))
idx2char = {k: v for k, v in enumerate(vocabulary, start=0)}
char2idx = {v: k for k, v in idx2char.items()}
# Out:
# 2350

# %%
class CustomDataset(Dataset):
    def __init__(self, img_path_list, label_list, train_mode=True):
        self.img_path_list = img_path_list
        self.label_list = label_list
        self.train_mode = train_mode

    def __len__(self):
        return len(self.img_path_list)

    def __getitem__(self, index):
        image = Image.open(self.img_path_list[index]).convert('RGB')

        if self.train_mode:
            image = self.train_transform(image)
        else:
            image = self.test_transform(image)

        if self.label_list is not None:
            text = self.label_list[index]
            return image, text
        else:
            return image

    # Image Augmentation
    def train_transform(self, image):
        transform_ops = transforms.Compose([
            transforms.Resize((CFG['IMG_HEIGHT_SIZE'], CFG['IMG_WIDTH_SIZE'])),
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.485, 0.456, 0.406),
                                 std=(0.229, 0.224, 0.225))
        ])
        return transform_ops(image)

    def test_transform(self, image):
        transform_ops = transforms.Compose([
            transforms.Resize((CFG['IMG_HEIGHT_SIZE'], CFG['IMG_WIDTH_SIZE'])),
            transforms.ToTensor(),
            transforms.Normalize(mean=(0.485, 0.456, 0.406),
                                 std=(0.229, 0.224, 0.225))
        ])
        return transform_ops(image)

# %%
train_dataset = CustomDataset(train['img_path'].values, train['label'].values)
train_loader = DataLoader(
    train_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=True, num_workers=CFG['NUM_WORKERS'])

val_dataset = CustomDataset(val['img_path'].values, val['label'].values)
val_loader = DataLoader(
    val_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=True, num_workers=CFG['NUM_WORKERS'])

# %%
image_batch, text_batch = iter(train_loader).next()
print(image_batch.size(), text_batch)
# Out:
# torch.Size([84, 3, 64, 224]) ('신비', '그나마', '씻기다', '쉴', '일반', '셋', '수입되다', '세', '달리다', '뜁', '선원', '추가', '대량', '예매하다', '콩', '쯩', '못', '사모님', '뱀', '호주머니', '젤', '벌', '불', '베개', '수도권', '회복되다', '날씨', '유산', '견해', '체조', '얘', '튀김', '삼계탕', '어려움', '세', '발자국', '터', '함께', '스타', '샛', '참여하다', '븐', '학생증', '신인', '신청', '양복', '추진하다', '집중하다', '구분되다', '기타', '지구', '꽐', '명예', '대륙', '천장', '신', '칡', '창조', '걋', '나무', '향', '여행사', '강', '흄', '출발', '전철', '꿈', '캠페인', '유산', '자극', '품', '대출', '관광버스', '내외', '법', '딱', '알리다', '먹이다', '왼발', '이제', '씁', '뒷골목', '만들다', '특정하다')

# %%
import torch.nn as nn

from modules.transformation import TPS_SpatialTransformerNetwork
from modules.feature_extraction import VGG_FeatureExtractor, RCNN_FeatureExtractor, ResNet_FeatureExtractor
from modules.sequence_modeling import BidirectionalLSTM
from modules.prediction import Attention


class Model(nn.Module):

    def __init__(self, num_class):
        super(Model, self).__init__()

        self.Transformation = TPS_SpatialTransformerNetwork(
            F=20, I_size=(CFG['IMG_HEIGHT_SIZE'], CFG['IMG_WIDTH_SIZE']), I_r_size=(CFG['IMG_HEIGHT_SIZE'], CFG['IMG_WIDTH_SIZE']), I_channel_num=3)

        """ FeatureExtraction """
        self.FeatureExtraction = ResNet_FeatureExtractor(3, 512)
        self.FeatureExtraction_output = 512
        self.AdaptiveAvgPool = nn.AdaptiveAvgPool2d(
            (None, 1))  # Transform final (imgH/16-1) -> 1

        """ Sequence modeling"""
        self.SequenceModeling = nn.Sequential(
            BidirectionalLSTM(self.FeatureExtraction_output,
                              512, 512),
            BidirectionalLSTM(512, 512, 512))
        self.SequenceModeling_output = 512

        """ Prediction """
        self.Prediction = nn.Linear(self.SequenceModeling_output, num_class)

    def forward(self, x):
        """ Transformation stage """
        input = self.Transformation(x)

        """ Feature extraction stage """
        visual_feature = self.FeatureExtraction(input)
        visual_feature = self.AdaptiveAvgPool(
            visual_feature.permute(0, 3, 1, 2))  # [b, c, h, w] -> [b, w, c, h]
        visual_feature = visual_feature.squeeze(3)

        """ Sequence modeling stage """
        contextual_feature = self.SequenceModeling(visual_feature)

        """ Prediction stage """
        prediction = self.Prediction(contextual_feature.contiguous())
        prediction = prediction.permute(1, 0, 2)

        return prediction

# %%
class RecognitionModel(nn.Module):
    def __init__(self, num_chars=len(char2idx), rnn_hidden_size=256):
        super(RecognitionModel, self).__init__()
        self.num_chars = num_chars
        self.rnn_hidden_size = rnn_hidden_size

        # CNN Backbone = 사전학습된 resnet18 활용
        # https://arxiv.org/abs/1512.03385
        resnet = resnet18(pretrained=True)
        # CNN Feature Extract
        resnet_modules = list(resnet.children())[:-3]
        self.feature_extract = nn.Sequential(
            *resnet_modules,
            nn.Conv2d(256, 256, kernel_size=(3, 6), stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
        )

        self.linear1 = nn.Linear(1024, rnn_hidden_size)

        # RNN
        self.rnn = nn.RNN(input_size=rnn_hidden_size,
                          hidden_size=rnn_hidden_size,
                          bidirectional=True,
                          batch_first=True)
        self.linear2 = nn.Linear(self.rnn_hidden_size*2, num_chars)

    def forward(self, x):
        # CNN
        x = self.feature_extract(x)  # [batch_size, channels, height, width]
        x = x.permute(0, 3, 1, 2)  # [batch_size, width, channels, height]

        batch_size = x.size(0)
        T = x.size(1)
        # [batch_size, T==width, num_features==channels*height]
        x = x.view(batch_size, T, -1)
        x = self.linear1(x)

        # RNN
        x, hidden = self.rnn(x)

        output = self.linear2(x)
        # [T==10, batch_size, num_classes==num_features]
        output = output.permute(1, 0, 2)

        return output

# %%
criterion = nn.CTCLoss(blank=0)  # idx 0 : '-'

# %%
def encode_text_batch(text_batch):
    text_batch_targets_lens = [len(text) for text in text_batch]
    text_batch_targets_lens = torch.IntTensor(text_batch_targets_lens)

    text_batch_concat = "".join(text_batch)
    text_batch_targets = [char2idx[c] for c in text_batch_concat]
    text_batch_targets = torch.IntTensor(text_batch_targets)

    return text_batch_targets, text_batch_targets_lens

# %%
def compute_loss(text_batch, text_batch_logits):
    """
    text_batch: list of strings of length equal to batch size
    text_batch_logits: Tensor of size([T, batch_size, num_classes])
    """
    text_batch_logps = F.log_softmax(
        text_batch_logits, 2)  # [T, batch_size, num_classes]
    text_batch_logps_lens = torch.full(size=(text_batch_logps.size(1),),
                                       fill_value=text_batch_logps.size(0),
                                       dtype=torch.int32).to(device)  # [batch_size]

    text_batch_targets, text_batch_targets_lens = encode_text_batch(text_batch)
    loss = criterion(text_batch_logps, text_batch_targets,
                     text_batch_logps_lens, text_batch_targets_lens)

    return loss

# %%
def train(model, optimizer, train_loader, val_loader, scheduler, device):
    model.to(device)

    best_loss = 999999
    best_model = None
    for epoch in range(1, CFG['EPOCHS']+1):
        model.train()
        train_loss = []
        for image_batch, text_batch in tqdm(iter(train_loader)):
            image_batch = image_batch.to(device)

            optimizer.zero_grad()
            text_batch_logits = model(image_batch)
            loss = compute_loss(text_batch, text_batch_logits)
            loss.backward()
            optimizer.step()
            train_loss.append(loss.item())

        _train_loss = np.mean(train_loss)

        _val_loss = validation(model, val_loader, device)
        print(
            f'Epoch : [{epoch}] Train CTC Loss : [{_train_loss:.5f}] Val CTC Loss : [{_val_loss:.5f}]')

        if scheduler is not None:
            scheduler.step(_val_loss)

        if best_loss > _val_loss:
            best_loss = _val_loss
            best_model = model

    return best_model

# %%
def validation(model, val_loader, device):
    model.eval()
    val_loss = []
    with torch.no_grad():
        for image_batch, text_batch in tqdm(iter(val_loader)):
            image_batch = image_batch.to(device)

            text_batch_logits = model(image_batch)
            loss = compute_loss(text_batch, text_batch_logits)

            val_loss.append(loss.item())

    _val_loss = np.mean(val_loss)
    return _val_loss

# %%
# torch.Size([16, 57, 2350])
# torch.Size([11, 16, 2350])

# %%
# model = RecognitionModel()

checkpoint = torch.load('./TPS-ResNet-BiLSTM-CTC.pth')
model = Model(len(char2idx))
model.load_state_dict(checkpoint, strict=False)
# model.eval()

# optim.Adadelta(filtered_parameters, lr=opt.lr, rho=opt.rho, eps=opt.eps)

optimizer = torch.optim.Adadelta(
    params=model.parameters(), lr=CFG["LEARNING_RATE"], rho=0.95, eps=1e-8)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=2, threshold_mode='abs', min_lr=1e-8, verbose=True)

infer_model = train(model, optimizer, train_loader,
                    val_loader, scheduler, device)
# Out:
#   0%|          | 0/789 [00:00<?, ?it/s]
#   0%|          | 0/127 [00:00<?, ?it/s]
# Epoch : [1] Train CTC Loss : [117.57431] Val CTC Loss : [8.28094]
#   0%|          | 0/789 [00:00<?, ?it/s]
#   0%|          | 0/127 [00:00<?, ?it/s]
# Epoch : [2] Train CTC Loss : [8.25000] Val CTC Loss : [8.08869]
#   0%|          | 0/789 [00:00<?, ?it/s]
#   0%|          | 0/127 [00:00<?, ?it/s]
# Epoch : [3] Train CTC Loss : [8.09440] Val CTC Loss : [7.95812]
#   0%|          | 0/789 [00:00<?, ?it/s]
#   0%|          | 0/127 [00:00<?, ?it/s]
# Epoch : [4] Train CTC Loss : [7.98275] Val CTC Loss : [7.85937]
#   0%|          | 0/789 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_743285/4196666353.py in <module>
#      14
#      15 infer_model = train(model, optimizer, train_loader,
# ---> 16                     val_loader, scheduler, device)
#
# /tmp/ipykernel_743285/364311759.py in train(model, optimizer, train_loader, val_loader, scheduler, device)
#      12             optimizer.zero_grad()
#      13             text_batch_logits = model(image_batch)
# ---> 14             loss = compute_loss(text_batch, text_batch_logits)
#      15             loss.backward()
#      16             optimizer.step()
#
# /tmp/ipykernel_743285/62268436.py in compute_loss(text_batch, text_batch_logits)
#       8     text_batch_logps_lens = torch.full(size=(text_batch_logps.size(1),),
#       9                                        fill_value=text_batch_logps.size(0),
# ---> 10                                        dtype=torch.int32).to(device)  # [batch_size]
#      11
#      12     text_batch_targets, text_batch_targets_lens = encode_text_batch(text_batch)
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), './model_pre_trained.pth')
torch.save(infer_model.state_dict(), './model_pre_trained_best.pth')

# %%
test = pd.read_csv('./test.csv')

# %%
test_dataset = CustomDataset(test['img_path'].values, None)
test_loader = DataLoader(
    test_dataset, batch_size=CFG['BATCH_SIZE'], shuffle=False, num_workers=CFG['NUM_WORKERS'])

# %%
def decode_predictions(text_batch_logits):
    text_batch_tokens = F.softmax(
        text_batch_logits, 2).argmax(2)  # [T, batch_size]
    text_batch_tokens = text_batch_tokens.numpy().T  # [batch_size, T]

    text_batch_tokens_new = []
    for text_tokens in text_batch_tokens:
        text = [idx2char[idx] for idx in text_tokens]
        text = "".join(text)
        text_batch_tokens_new.append(text)

    return text_batch_tokens_new


def inference(model, test_loader, device):
    model.eval()
    preds = []
    with torch.no_grad():
        for image_batch in tqdm(iter(test_loader)):
            image_batch = image_batch.to(device)

            text_batch_logits = model(image_batch)

            text_batch_pred = decode_predictions(text_batch_logits.cpu())

            preds.extend(text_batch_pred)
    return preds

# %%
predictions = inference(infer_model, test_loader, device)
# Out:
#   0%|          | 0/883 [00:00<?, ?it/s]

# %%
# 샘플 별 추론결과를 독립적으로 후처리
def remove_duplicates(text):
    if len(text) > 1:
        letters = [text[0]] + [letter for idx,
                               letter in enumerate(text[1:], start=1) if text[idx] != text[idx-1]]
    elif len(text) == 1:
        letters = [text[0]]
    else:
        return ""
    return "".join(letters)


def correct_prediction(word):
    parts = word.split("-")
    parts = [remove_duplicates(part) for part in parts]
    corrected_word = "".join(parts)
    return corrected_word

# %%
submit = pd.read_csv('./sample_submission.csv')
submit['label'] = predictions
submit['label'] = submit['label'].apply(correct_prediction)

# %%
submit.to_csv('./submission_rev.csv', index=False)
